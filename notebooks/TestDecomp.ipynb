# %% [markdown]
# # Test 'decomp' option

# %%
import xarray as xr

# %%
outputs_dir = '../outputs/'
ds = xr.open_dataset(f'{outputs_dir}SeaLevelPerc_AR5_glo_decomp_rcp45.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (percentiles: 11, proc: 11, proc3: 7, time: 95, time_s: 10)
# Coordinates:
#   * proc         (proc) object 'Global steric' 'Local ocean' ... 'Total'
#   * percentiles  (percentiles) int64 1 5 10 17 20 50 80 83 90 95 99
#   * time         (time) int64 2006 2007 2008 2009 2010 ... 2097 2098 2099 2100
#   * proc3        (proc3) object 'Thermal exp.' 'Glaciers' ... 'Green dyn.'
#   * time_s       (time_s) int64 2010 2020 2030 2040 2050 ... 2070 2080 2090 2100
# Data variables:
#     perc_ts      (proc, percentiles, time) float64 ...
#     decomp       (proc3, percentiles, time_s) float64 ...
# Attributes:
#     options:        Computations were done with the following options:: Local...
#     source_file:    This NetCDF file was built from the Probabilistic Sea Lev...
#     creation_date:  2020-12-30 14:58

# %%
sum_pc = ds.decomp.sum(dim='proc3')

# %%
perc = 95
ds.perc_ts.sel(percentiles=perc,proc='Total').plot()
sum_pc.sel(percentiles=perc).plot()
